# %%
import baccoemu
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [14,8]
font = {'size'   : 16, 'family':'STIXGeneral'}
axislabelfontsize='x-large'
plt.rc('font', **font)
plt.rcParams['text.usetex'] = True
np.set_printoptions(precision=3,linewidth=200,suppress=False)
#mpk_emulator = baccoemu.Matter_powerspectrum(verbose=False)
#lbias_emulator = baccoemu.Lbias_expansion(verbose=False)
# Out:
# 2024-08-28 10:58:55.535278: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-28 10:58:55.588677: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-28 10:58:55.589700: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-28 10:58:56.528719: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
cosmopars = {
    'omega_cold'    :  0.1,
    'sigma8_cold'   :  0.815, # if A_s is not specified
    'omega_baryon'  :  0.05,
    'ns'            :  0.96,
    'hubble'        :  0.67,
    'neutrino_mass' :  0.0,
    'w0'            : -1.0,
    'wa'            :  0.0,
    'expfactor'     :  1
    }

# %%
cosmotheka
# Out:
# <module 'cl_like' from '/home/andrea/anaconda3/envs/extrapolation_bacco_env/lib/python3.11/site-packages/cl_like/cl_like.py'>
